# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers=['kafka:9092'],
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

user_ids = [101, 102, 103, 104, 105]

print("Starting Transaction Producer...")

for i in range(100):
    tx_data = {
        "tx_id": i,
        "userId": random.choice(user_ids),
        "amount": random.uniform(10.0, 15000.0), # >10000 triggers fraud
        "timestamp": time.time()
    }
    producer.send('fraud-alerts5', value=tx_data)
    print(f"Sent: {tx_data}")
    time.sleep(2)
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 102, 'amount': 13712.056304384429, 'timestamp': 1781849978.2366679}
# Sent: {'tx_id': 1, 'userId': 102, 'amount': 1363.430895741098, 'timestamp': 1781849980.3306699}
# Sent: {'tx_id': 2, 'userId': 101, 'amount': 1710.321272018688, 'timestamp': 1781849982.3311765}
# Sent: {'tx_id': 3, 'userId': 104, 'amount': 7423.821221511629, 'timestamp': 1781849984.3324192}
# Sent: {'tx_id': 4, 'userId': 104, 'amount': 11774.631671092475, 'timestamp': 1781849986.3340826}
# Sent: {'tx_id': 5, 'userId': 102, 'amount': 453.23237334893815, 'timestamp': 1781849988.3346658}
# Sent: {'tx_id': 6, 'userId': 105, 'amount': 1783.6884746332232, 'timestamp': 1781849990.3369713}
# Sent: {'tx_id': 7, 'userId': 105, 'amount': 525.275284540537, 'timestamp': 1781849992.3374486}
# Sent: {'tx_id': 8, 'userId': 104, 'amount': 1590.4764657135859, 'timestamp': 1781849994.3384423}
# Sent: {'tx_id': 9, 'userId': 101, 'amount': 8690.551806909856, 'timestamp': 1781849996.3389456}
# Sent: {'tx_id': 10, 'userId': 104, 'amount': 2351.852943781893, 'timestamp': 1781849998.3395448}
# Sent: {'tx_id': 11, 'userId': 103, 'amount': 3558.386969604873, 'timestamp': 1781850000.3436933}
# Sent: {'tx_id': 12, 'userId': 101, 'amount': 9866.43999940174, 'timestamp': 1781850002.344674}
# Sent: {'tx_id': 13, 'userId': 105, 'amount': 36.299762097897386, 'timestamp': 1781850004.3453255}
# Sent: {'tx_id': 14, 'userId': 102, 'amount': 4242.823483326893, 'timestamp': 1781850006.3472748}
# Sent: {'tx_id': 15, 'userId': 102, 'amount': 5271.274737270359, 'timestamp': 1781850008.349046}
# Sent: {'tx_id': 16, 'userId': 104, 'amount': 7911.683088209948, 'timestamp': 1781850010.3505387}
# Sent: {'tx_id': 17, 'userId': 101, 'amount': 5003.052859321387, 'timestamp': 1781850012.351615}
# Sent: {'tx_id': 18, 'userId': 102, 'amount': 6029.395454562432, 'timestamp': 1781850014.3521633}
# Sent: {'tx_id': 19, 'userId': 102, 'amount': 10948.735554684312, 'timestamp': 1781850016.3526511}
# Sent: {'tx_id': 20, 'userId': 101, 'amount': 5573.4247887676, 'timestamp': 1781850018.3537865}
# Sent: {'tx_id': 21, 'userId': 104, 'amount': 14903.121666579782, 'timestamp': 1781850020.355529}
# Sent: {'tx_id': 22, 'userId': 104, 'amount': 574.1234836760796, 'timestamp': 1781850022.3559754}
# Sent: {'tx_id': 23, 'userId': 102, 'amount': 9932.392201053955, 'timestamp': 1781850024.3576992}
# Sent: {'tx_id': 24, 'userId': 102, 'amount': 13140.717648899976, 'timestamp': 1781850026.3583794}
# Sent: {'tx_id': 25, 'userId': 105, 'amount': 9123.414971645723, 'timestamp': 1781850028.3598983}
# Sent: {'tx_id': 26, 'userId': 101, 'amount': 10596.560947075624, 'timestamp': 1781850030.3605692}
# Sent: {'tx_id': 27, 'userId': 105, 'amount': 3884.6009192054935, 'timestamp': 1781850032.36152}
# Sent: {'tx_id': 28, 'userId': 104, 'amount': 12623.93140492296, 'timestamp': 1781850034.3637815}
# Sent: {'tx_id': 29, 'userId': 104, 'amount': 13035.69231223375, 'timestamp': 1781850036.364428}
# Sent: {'tx_id': 30, 'userId': 101, 'amount': 1389.1138930579743, 'timestamp': 1781850038.3650777}
# Sent: {'tx_id': 31, 'userId': 104, 'amount': 8185.07705372836, 'timestamp': 1781850040.3663394}
# Sent: {'tx_id': 32, 'userId': 102, 'amount': 9814.539638886075, 'timestamp': 1781850042.3669593}
# Sent: {'tx_id': 33, 'userId': 102, 'amount': 1024.690017383083, 'timestamp': 1781850044.3674338}
# Sent: {'tx_id': 34, 'userId': 101, 'amount': 11742.187794725834, 'timestamp': 1781850046.368625}
# Sent: {'tx_id': 35, 'userId': 104, 'amount': 8404.072235481275, 'timestamp': 1781850048.3690858}
# Sent: {'tx_id': 36, 'userId': 105, 'amount': 1262.8802375041994, 'timestamp': 1781850050.3702803}
# Sent: {'tx_id': 37, 'userId': 103, 'amount': 7766.195649638093, 'timestamp': 1781850052.3709974}
# Sent: {'tx_id': 38, 'userId': 104, 'amount': 4188.062423012757, 'timestamp': 1781850054.3721843}
# Sent: {'tx_id': 39, 'userId': 102, 'amount': 8320.711798588023, 'timestamp': 1781850056.3727942}
# Sent: {'tx_id': 40, 'userId': 102, 'amount': 14828.746866564734, 'timestamp': 1781850058.3732646}
# Sent: {'tx_id': 41, 'userId': 103, 'amount': 4624.19863868342, 'timestamp': 1781850060.3737178}
# Sent: {'tx_id': 42, 'userId': 101, 'amount': 9930.684597299569, 'timestamp': 1781850062.3749504}
# Sent: {'tx_id': 43, 'userId': 101, 'amount': 2206.288694118522, 'timestamp': 1781850064.3754807}
# Sent: {'tx_id': 44, 'userId': 105, 'amount': 11093.833983906567, 'timestamp': 1781850066.3763623}
# Sent: {'tx_id': 45, 'userId': 104, 'amount': 6297.227440213129, 'timestamp': 1781850068.3816729}
# Sent: {'tx_id': 46, 'userId': 104, 'amount': 969.1827816555788, 'timestamp': 1781850070.382469}
# Sent: {'tx_id': 47, 'userId': 104, 'amount': 11751.53414363756, 'timestamp': 1781850072.3831553}
# Sent: {'tx_id': 48, 'userId': 101, 'amount': 9151.491567115218, 'timestamp': 1781850074.3835983}
# Sent: {'tx_id': 49, 'userId': 102, 'amount': 11120.625521718799, 'timestamp': 1781850076.3853295}
# Sent: {'tx_id': 50, 'userId': 101, 'amount': 3201.9625513176843, 'timestamp': 1781850078.3858678}
# Sent: {'tx_id': 51, 'userId': 102, 'amount': 13393.756143004599, 'timestamp': 1781850080.386401}
# Sent: {'tx_id': 52, 'userId': 102, 'amount': 7455.456381542313, 'timestamp': 1781850082.3870406}
# Sent: {'tx_id': 53, 'userId': 101, 'amount': 10009.945566468417, 'timestamp': 1781850084.3889506}
# Sent: {'tx_id': 54, 'userId': 102, 'amount': 8512.910461313018, 'timestamp': 1781850086.3895133}
# Sent: {'tx_id': 55, 'userId': 102, 'amount': 2386.422741505027, 'timestamp': 1781850088.3916702}
# Sent: {'tx_id': 56, 'userId': 101, 'amount': 1838.5944104332027, 'timestamp': 1781850090.39215}
# Sent: {'tx_id': 57, 'userId': 105, 'amount': 9738.256704977592, 'timestamp': 1781850092.3979218}
# Sent: {'tx_id': 58, 'userId': 102, 'amount': 10452.32150543577, 'timestamp': 1781850094.3985963}
# Sent: {'tx_id': 59, 'userId': 104, 'amount': 810.2253655645949, 'timestamp': 1781850096.399275}
# Sent: {'tx_id': 60, 'userId': 102, 'amount': 12232.599591345856, 'timestamp': 1781850098.3998444}
# Sent: {'tx_id': 61, 'userId': 103, 'amount': 11951.415561672604, 'timestamp': 1781850100.4003026}
# Sent: {'tx_id': 62, 'userId': 104, 'amount': 2265.041670848077, 'timestamp': 1781850102.4014428}
# Sent: {'tx_id': 63, 'userId': 104, 'amount': 12833.754466602755, 'timestamp': 1781850104.4018815}
# Sent: {'tx_id': 64, 'userId': 103, 'amount': 10551.290666036002, 'timestamp': 1781850106.4031444}
# Sent: {'tx_id': 65, 'userId': 103, 'amount': 481.96693147629793, 'timestamp': 1781850108.403609}
# Sent: {'tx_id': 66, 'userId': 104, 'amount': 13810.190653284739, 'timestamp': 1781850110.4046772}
# Sent: {'tx_id': 67, 'userId': 101, 'amount': 14459.48807875934, 'timestamp': 1781850112.4053164}
# Sent: {'tx_id': 68, 'userId': 104, 'amount': 11840.28627817213, 'timestamp': 1781850114.4057984}
# Sent: {'tx_id': 69, 'userId': 101, 'amount': 384.07221015866304, 'timestamp': 1781850116.4073877}
# Sent: {'tx_id': 70, 'userId': 104, 'amount': 5115.203243182991, 'timestamp': 1781850118.4080784}
# Sent: {'tx_id': 71, 'userId': 101, 'amount': 3407.7810119694195, 'timestamp': 1781850120.4095442}
# Sent: {'tx_id': 72, 'userId': 103, 'amount': 12849.321681813635, 'timestamp': 1781850122.4102602}
# Sent: {'tx_id': 73, 'userId': 105, 'amount': 12012.740522808821, 'timestamp': 1781850124.4114397}
# Sent: {'tx_id': 74, 'userId': 101, 'amount': 9667.416435380524, 'timestamp': 1781850126.4119534}
# Sent: {'tx_id': 75, 'userId': 101, 'amount': 515.8284219078437, 'timestamp': 1781850128.4129863}
# Sent: {'tx_id': 76, 'userId': 104, 'amount': 5270.449990266974, 'timestamp': 1781850130.4161682}
# Sent: {'tx_id': 77, 'userId': 105, 'amount': 7535.104179891151, 'timestamp': 1781850132.4166224}
# Sent: {'tx_id': 78, 'userId': 104, 'amount': 3720.417965040799, 'timestamp': 1781850134.4170861}
# Sent: {'tx_id': 79, 'userId': 103, 'amount': 1832.9763622770092, 'timestamp': 1781850136.418318}
# Sent: {'tx_id': 80, 'userId': 104, 'amount': 8848.47889316475, 'timestamp': 1781850138.4187715}
# Sent: {'tx_id': 81, 'userId': 101, 'amount': 10335.197741093063, 'timestamp': 1781850140.41989}
# Sent: {'tx_id': 82, 'userId': 101, 'amount': 36.457584867778834, 'timestamp': 1781850142.420367}
# Sent: {'tx_id': 83, 'userId': 102, 'amount': 11181.684212877633, 'timestamp': 1781850144.42081}
# Sent: {'tx_id': 84, 'userId': 101, 'amount': 7539.776618945146, 'timestamp': 1781850146.4214842}
# Sent: {'tx_id': 85, 'userId': 102, 'amount': 1450.9112436436608, 'timestamp': 1781850148.4229803}
# Sent: {'tx_id': 86, 'userId': 102, 'amount': 12582.757053307749, 'timestamp': 1781850150.423451}
# Sent: {'tx_id': 87, 'userId': 101, 'amount': 1512.718805734598, 'timestamp': 1781850152.4240873}
# Sent: {'tx_id': 88, 'userId': 103, 'amount': 6645.887958331389, 'timestamp': 1781850154.4245293}
# Sent: {'tx_id': 89, 'userId': 104, 'amount': 232.52532419871963, 'timestamp': 1781850156.4252822}
# Sent: {'tx_id': 90, 'userId': 105, 'amount': 11690.243093796727, 'timestamp': 1781850158.4257324}
# Sent: {'tx_id': 91, 'userId': 101, 'amount': 4883.269225479786, 'timestamp': 1781850160.4262226}
# Sent: {'tx_id': 92, 'userId': 101, 'amount': 8388.118928079779, 'timestamp': 1781850162.4266684}
# Sent: {'tx_id': 93, 'userId': 102, 'amount': 93.04094126510932, 'timestamp': 1781850164.4271715}
# Sent: {'tx_id': 94, 'userId': 105, 'amount': 2790.373593001325, 'timestamp': 1781850166.4278412}
# Sent: {'tx_id': 95, 'userId': 101, 'amount': 13674.792022950674, 'timestamp': 1781850168.4283152}
# Sent: {'tx_id': 96, 'userId': 105, 'amount': 6148.779040274703, 'timestamp': 1781850170.4300768}
# Sent: {'tx_id': 97, 'userId': 102, 'amount': 2097.2217187059623, 'timestamp': 1781850172.4322186}
# Sent: {'tx_id': 98, 'userId': 105, 'amount': 8397.670990542487, 'timestamp': 1781850174.4334466}
# Sent: {'tx_id': 99, 'userId': 101, 'amount': 4517.226582518895, 'timestamp': 1781850176.4338968}
